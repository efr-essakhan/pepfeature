# %% [markdown]
# **Data set:**
#
# Ov_data.csv: this is a sample data set related to a specific organism. The important column in this data set is names "Info_window_seq". It contains 15-character strings representing fixed-length protein fragments (called "peptides") generated by running a sliding window over the organism protein strings.
#
# **Initial features to calculate:**
#
# Proteins are composed of 20 aminoacids, represented by different letters. Valid letters are: A, C, D, E, F, G, H, I, K, L, M, N, P, Q, R, S, T, V, W, Y.
#
# 1) We need to calculate the percent of each aminoacid in the peptides.
# 2) This will result in 20 features (columns), which should be called
#
# feat_perc_A, feat_perc_C, ..., feat_perc_Y.
#
# **Notes:**
#
# 1) The frequency is calculated as (number_of_occurrences_of_letter / length_of_peptide)
#
# 2) if a letter does not occur in a given peptide it should have a frequency of zero.
#
# 3) if an invalid letter appears in the sequence, it should be removed before the frequencies are calculated.

# %%
import numpy as np
import pandas as pd
import time

# %%
df = pd.read_csv('Ov_data.csv')

#Create columns
for letter in valid_letters:
    df['feat_perc_{}'.format(letter)] = 0

# %%
valid_letters = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']

# %%
def peptides_feature_generator(peptide_row):

    length_of_peptide = 15
    number_of_occurrences_of_letter_dict = {'A':0,'C':0, 'D':0, 'E':0, 'F':0, 'G':0, 'H':0, 'I':0, 'K':0, 'L':0, 'M':0, 'N':0, 'P':0, 'Q':0, 'R':0, 'S':0, 'T':0, 'V':0, 'W':0, 'Y':0}
    
    # 1) Find out number of occurences of each letter in the peptide & confirm peptide length
    for i in range(15):
        peptide_letter = peptide_row['Info_window_seq'][i]
        
        if peptide_letter in valid_letters:
            number_of_occurrences_of_letter_dict[peptide_letter] += 1
            
        else:
            length_of_peptide -= 1
            
                
    # 2) Find out the percentage of each letter in the peptides
    for key, value in number_of_occurrences_of_letter_dict.items():

        df.loc[peptide_row.name, 'feat_perc_{}'.format(key)] = (value / length_of_peptide) * 100

# %% [markdown]
# **Running the code on dataframe (Ov_data.csv)**

# %%
start_time = time.time()
df.apply(peptides_feature_generator, axis=1)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 818.1764192581177 seconds ---

# %%
df[['Info_window_seq', 'feat_perc_A',
       'feat_perc_C', 'feat_perc_D', 'feat_perc_E', 'feat_perc_F',
       'feat_perc_G', 'feat_perc_H', 'feat_perc_I', 'feat_perc_K',
       'feat_perc_L', 'feat_perc_M', 'feat_perc_N', 'feat_perc_P',
       'feat_perc_Q', 'feat_perc_R', 'feat_perc_S', 'feat_perc_T',
       'feat_perc_V', 'feat_perc_W', 'feat_perc_Y']]
# Out:
#        Info_window_seq  feat_perc_A  feat_perc_C  feat_perc_D  feat_perc_E  \
# 0      LLLLLLLLDVHIESG     0.000000     0.000000     6.666667     6.666667
# 1      LLLLLLLDVHIESGE     0.000000     0.000000     6.666667    13.333333
# 2      LLLLLLDVHIESGEV     0.000000     0.000000     6.666667    13.333333
# 3      LLLLLDVHIESGEVC     0.000000     6.666667     6.666667    13.333333
# 4      LLLLDVHIESGEVCA     6.666667     6.666667     6.666667    13.333333
# ...                ...          ...          ...          ...          ...
# 88837  AKKLKELSKRATFVR    13.333333     0.000000     0.000000     6.666667
# 88838  KKLKELSKRATFVRV     6.666667     0.000000     0.000000     6.666667
# 88839  KLKELSKRATFVRVT     6.666667     0.000000     0.000000     6.666667
# 88840  LKELSKRATFVRVTQ     6.666667     0.000000     0.000000     6.666667
# 88841  KELSKRATFVRVTQQ     6.666667     0.000000     0.000000     6.666667
#
#        feat_perc_F  feat_perc_G  feat_perc_H  feat_perc_I  feat_perc_K  ...  \
# 0         0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 1         0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 2         0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 3         0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 4         0.000000     6.666667     6.666667     6.666667     0.000000  ...
# ...            ...          ...          ...          ...          ...  ...
# 88837     6.666667     0.000000     0.000000     0.000000    26.666667  ...
# 88838     6.666667     0.000000     0.000000     0.000000    26.666667  ...
# 88839     6.666667     0.000000     0.000000     0.000000    20.000000  ...
# 88840     6.666667     0.000000     0.000000     0.000000    13.333333  ...
# 88841     6.666667     0.000000     0.000000     0.000000    13.333333  ...
#
#        feat_perc_M  feat_perc_N  feat_perc_P  feat_perc_Q  feat_perc_R  \
# 0              0.0          0.0          0.0     0.000000     0.000000
# 1              0.0          0.0          0.0     0.000000     0.000000
# 2              0.0          0.0          0.0     0.000000     0.000000
# 3              0.0          0.0          0.0     0.000000     0.000000
# 4              0.0          0.0          0.0     0.000000     0.000000
# ...            ...          ...          ...          ...          ...
# 88837          0.0          0.0          0.0     0.000000    13.333333
# 88838          0.0          0.0          0.0     0.000000    13.333333
# 88839          0.0          0.0          0.0     0.000000    13.333333
# 88840          0.0          0.0          0.0     6.666667    13.333333
# 88841          0.0          0.0          0.0    13.333333    13.333333
#
#        feat_perc_S  feat_perc_T  feat_perc_V  feat_perc_W  feat_perc_Y
# 0         6.666667     0.000000     6.666667          0.0          0.0
# 1         6.666667     0.000000     6.666667          0.0          0.0
# 2         6.666667     0.000000    13.333333          0.0          0.0
# 3         6.666667     0.000000    13.333333          0.0          0.0
# 4         6.666667     0.000000    13.333333          0.0          0.0
# ...            ...          ...          ...          ...          ...
# 88837     6.666667     6.666667     6.666667          0.0          0.0
# 88838     6.666667     6.666667    13.333333          0.0          0.0
# 88839     6.666667    13.333333    13.333333          0.0          0.0
# 88840     6.666667    13.333333    13.333333          0.0          0.0
# 88841     6.666667    13.333333    13.333333          0.0          0.0
#
# [88842 rows x 21 columns]

# %% [markdown]
# **Testing the code with subset of dataframe**

# %%
start_time = time.time()


df.loc[range(10)].apply(peptides_feature_generator, axis=1)

print("--- %s seconds ---" % (time.time() - start_time))

print(df.loc[range(10), ['Info_window_seq', 'feat_perc_A',
       'feat_perc_C', 'feat_perc_D', 'feat_perc_E', 'feat_perc_F',
       'feat_perc_G', 'feat_perc_H', 'feat_perc_I', 'feat_perc_K',
       'feat_perc_L', 'feat_perc_M', 'feat_perc_N', 'feat_perc_P',
       'feat_perc_Q', 'feat_perc_R', 'feat_perc_S', 'feat_perc_T',
       'feat_perc_V', 'feat_perc_W', 'feat_perc_Y']])
# Out:
# --- 0.10895776748657227 seconds ---
#    Info_window_seq  feat_perc_A  feat_perc_C  feat_perc_D  feat_perc_E  \
# 0  LLLLLLLLDVHIESG     0.000000     0.000000     6.666667     6.666667
# 1  LLLLLLLDVHIESGE     0.000000     0.000000     6.666667    13.333333
# 2  LLLLLLDVHIESGEV     0.000000     0.000000     6.666667    13.333333
# 3  LLLLLDVHIESGEVC     0.000000     6.666667     6.666667    13.333333
# 4  LLLLDVHIESGEVCA     6.666667     6.666667     6.666667    13.333333
# 5  LLLDVHIESGEVCAM     6.666667     6.666667     6.666667    13.333333
# 6  LLDVHIESGEVCAMV     6.666667     6.666667     6.666667    13.333333
# 7  LDVHIESGEVCAMVF     6.666667     6.666667     6.666667    13.333333
# 8  DVHIESGEVCAMVFR     6.666667     6.666667     6.666667    13.333333
# 9  VHIESGEVCAMVFRK     6.666667     6.666667     0.000000    13.333333
#
#    feat_perc_F  feat_perc_G  feat_perc_H  feat_perc_I  feat_perc_K  ...  \
# 0     0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 1     0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 2     0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 3     0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 4     0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 5     0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 6     0.000000     6.666667     6.666667     6.666667     0.000000  ...
# 7     6.666667     6.666667     6.666667     6.666667     0.000000  ...
# 8     6.666667     6.666667     6.666667     6.666667     0.000000  ...
# 9     6.666667     6.666667     6.666667     6.666667     6.666667  ...
#
#    feat_perc_M  feat_perc_N  feat_perc_P  feat_perc_Q  feat_perc_R  \
# 0     0.000000          0.0          0.0          0.0     0.000000
# 1     0.000000          0.0          0.0          0.0     0.000000
# 2     0.000000          0.0          0.0          0.0     0.000000
# 3     0.000000          0.0          0.0          0.0     0.000000
# 4     0.000000          0.0          0.0          0.0     0.000000
# 5     6.666667          0.0          0.0          0.0     0.000000
# 6     6.666667          0.0          0.0          0.0     0.000000
# 7     6.666667          0.0          0.0          0.0     0.000000
# 8     6.666667          0.0          0.0          0.0     6.666667
# 9     6.666667          0.0          0.0          0.0     6.666667
#
#    feat_perc_S  feat_perc_T  feat_perc_V  feat_perc_W  feat_perc_Y
# 0     6.666667          0.0     6.666667          0.0          0.0
# 1     6.666667          0.0     6.666667          0.0          0.0
# 2     6.666667          0.0    13.333333          0.0          0.0
# 3     6.666667          0.0    13.333333          0.0          0.0
# 4     6.666667          0.0    13.333333          0.0          0.0
# 5     6.666667          0.0    13.333333          0.0          0.0
# 6     6.666667          0.0    20.000000          0.0          0.0
# 7     6.666667          0.0    20.000000          0.0          0.0
# 8     6.666667          0.0    20.000000          0.0          0.0
# 9     6.666667          0.0    20.000000          0.0          0.0
#
# [10 rows x 21 columns]
